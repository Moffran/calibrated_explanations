# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import pandas as pd
import pickle
import warnings

from scipy import stats

# Ignore all warnings
warnings.filterwarnings('ignore')

# %%
with open('../results_regression_test.pkl', 'rb') as f:
    results = pickle.load(f)

# %%
base_names = ['LIME', 'SHAP', 'CE', 'PCE', 'FCE', 'PFCE']
norm_names = ['', ' Dist', ' Std', ' Abs', ' Var']
setup_names = {'lime_base': 'LIME Base', 'shap_base': 'SHAP Base'}
for i, base in enumerate(['lime', 'shap', 'ce', 'pce', 'fce', 'pfce']):
    for j, setup in enumerate(['']):#['', '_dist', '_std', '_abs', '_var']
        setup_names[base + setup] = base_names[i] + norm_names[j]
setup_names
# Out:
# {'lime_base': 'LIME Base',
#  'shap_base': 'SHAP Base',
#  'lime': 'LIME',
#  'shap': 'SHAP',
#  'ce': 'CE',
#  'pce': 'PCE',
#  'fce': 'FCE',
#  'pfce': 'PFCE'}

# %%
results.keys()
filtered_results = {k: v for k, v in results.items() if k not in ['num_rep', 'test_size',]}
filtered_results.keys()
# Out:
# dict_keys(['abalone', 'anacalt', 'bank8fh', 'bank8fm', 'bank8nh', 'bank8nm', 'comp', 'concreate', 'deltaA', 'deltaE', 'friedm', 'kin8fh', 'kin8fm'])

# %%
stab_data = []
rob_data = []
for key in filtered_results.keys():
    for setup in filtered_results[key]['RF']['rob_timer'].keys():
        stab_data.append([key, setup_names[setup], np.mean(filtered_results[key]['RF']['stab_timer'][setup])])
        rob_data.append([key, setup_names[setup], np.mean(filtered_results[key]['RF']['rob_timer'][setup])])

stab_df = pd.DataFrame(stab_data, columns=['Dataset', 'Setup', 'Value'])
rob_df = pd.DataFrame(rob_data, columns=['Dataset', 'Setup', 'Value'])
stab_df
# Out:
#      Dataset      Setup     Value
# 0    abalone  LIME Base  0.067788
# 1    abalone  SHAP Base  0.174447
# 2    abalone       LIME  0.084621
# 3    abalone       SHAP  0.275304
# 4    abalone         CE  0.024831
# ..       ...        ...       ...
# 99    kin8fm       SHAP  0.282757
# 100   kin8fm         CE  0.021285
# 101   kin8fm        PCE  0.023958
# 102   kin8fm        FCE  0.001533
# 103   kin8fm       PFCE  0.003690
#
# [104 rows x 3 columns]

# %%
import pandas as pd
import numpy as np

# Assuming stab_df and rob_df are already defined

# Define the order of the 'Setup' column
setup_order = stab_df['Setup'].unique()  # or specify the order explicitly: ['Setup1', 'Setup2', ...]

# Convert 'Setup' column to categorical with the specified order
stab_df['Setup'] = pd.Categorical(stab_df['Setup'], categories=setup_order, ordered=True)
rob_df['Setup'] = pd.Categorical(rob_df['Setup'], categories=setup_order, ordered=True)

stab_pivot = stab_df.pivot(index='Dataset', columns='Setup', values='Value')
rob_pivot = rob_df.pivot(index='Dataset', columns='Setup', values='Value')

display(stab_pivot) 
display(stab_df.pivot_table(columns='Setup', values=['Value'], aggfunc=[np.mean]))
display(rob_pivot)
display(rob_df.pivot_table(columns='Setup', values=['Value'], aggfunc=[np.mean]))
stab_pivot.to_csv('stab_time.csv')
rob_pivot.to_csv('rob_time.csv')
# Out:
# Setup      LIME Base  SHAP Base      LIME      SHAP        CE       PCE  \
# Dataset
# abalone     0.067788   0.174447  0.084621  0.275304  0.024831  0.026518
# anacalt     0.034124   0.029149  0.051255  0.055422  0.017460  0.017843
# bank8fh     0.100471   0.226509  0.121452  0.313441  0.025248  0.029217
# bank8fm     0.095049   0.208958  0.114278  0.295629  0.026522  0.028002
# bank8nh     0.093580   0.200796  0.106965  0.267743  0.021507  0.022601
# bank8nm     0.091514   0.197085  0.107576  0.270357  0.020962  0.021754
# comp        0.078666   0.491732  0.092123  0.629910  0.040154  0.042431
# concreate   0.058012   0.125043  0.077364  0.199336  0.022047  0.023933
# deltaA      0.109278   0.044007  0.125049  0.054907  0.011052  0.013160
# deltaE      0.131697   0.056258  0.143619  0.071444  0.013690  0.015685
# friedm      0.087285   0.031497  0.103561  0.042903  0.010931  0.012235
# kin8fh      0.120941   0.255398  0.145315  0.363798  8.473451  0.040118
# kin8fm      0.088800   0.204991  0.103538  0.282757  0.021285  0.023958
#
# Setup           FCE      PFCE
# Dataset
# abalone    0.001749  0.003212
# anacalt    0.001052  0.001961
# bank8fh    0.002002  0.004024
# bank8fm    0.002174  0.004747
# bank8nh    0.001409  0.003945
# bank8nm    0.001413  0.003325
# comp       0.001743  0.003729
# concreate  0.000947  0.002622
# deltaA     0.001091  0.002470
# deltaE     0.001203  0.003017
# friedm     0.000733  0.001739
# kin8fh     0.002761  0.006522
# kin8fm     0.001533  0.003690
#            mean                                                             \
# Setup LIME Base SHAP Base      LIME      SHAP        CE      PCE       FCE
# Value  0.089016  0.172759  0.105901  0.240227  0.671472  0.02442  0.001524
#
#
# Setup      PFCE
# Value  0.003462
# Setup      LIME Base  SHAP Base      LIME      SHAP        CE       PCE  \
# Dataset
# abalone     0.065493   0.166342  0.086241  0.271425  0.025526  0.025917
# anacalt     0.034767   0.029206  0.054598  0.051994  0.017715  0.018487
# bank8fh     0.100758   0.224431  0.122409  0.323049  0.026630  0.027974
# bank8fm     0.094931   0.204393  0.108948  0.273555  0.023897  0.026284
# bank8nh     0.093583   0.201941  0.107068  0.267728  0.020472  0.022645
# bank8nm     0.094140   0.206443  0.108797  0.265597  0.021313  0.022412
# comp        0.080680   0.497250  0.096769  0.646715  0.042910  0.045764
# concreate   0.056929   0.115863  0.075434  0.185994  0.022760  0.022280
# deltaA      0.104802   0.042765  0.120296  0.053481  0.010734  0.011739
# deltaE      0.126806   0.055464  0.140995  0.068406  0.013159  0.014591
# friedm      0.084022   0.032074  0.100943  0.043410  0.010344  0.011162
# kin8fh      0.096707   0.235227  0.111177  0.299001  0.023806  0.026154
# kin8fm      0.090921   0.207337  0.103515  0.288197  0.021228  0.024180
#
# Setup           FCE      PFCE
# Dataset
# abalone    0.001290  0.003758
# anacalt    0.000828  0.001876
# bank8fh    0.002402  0.004645
# bank8fm    0.001548  0.003853
# bank8nh    0.001430  0.003790
# bank8nm    0.001430  0.003792
# comp       0.001820  0.004040
# concreate  0.000940  0.002430
# deltaA     0.001009  0.002902
# deltaE     0.001176  0.003108
# friedm     0.000718  0.002032
# kin8fh     0.001835  0.004708
# kin8fm     0.001577  0.003850
#            mean                                                              \
# Setup LIME Base SHAP Base      LIME      SHAP        CE       PCE       FCE
# Value  0.086503  0.170672  0.102861  0.233735  0.021577  0.023045  0.001385
#
#
# Setup      PFCE
# Value  0.003445

# %%
stab = 'Stability'
rob = 'Robustness'

dataset = {}
for key in filtered_results.keys():
    stability = filtered_results[key]['RF']['stability']
    robustness = filtered_results[key]['RF']['robustness']

    performance = {
        stab: {},
        rob: {},
        'Prediction Variance': np.mean(
            [
                np.var(
                    [
                        robustness['predict'][i][j]
                        for i in range(len(robustness['predict']))
                    ]
                )
                for j in range(len(robustness['predict'][0]))
            ]
        ),
    }
    try:
        for setup in stability.keys():
            # Get the most important feature for each instance using the absolute value of the feature weights
            stab_feature = []
            rob_feature = []
            for j in range(len(stability[setup][0])): # number of instances        
                stab_feature.append([np.argmax(np.abs(stability[setup][i][j]['predict'])) for i in range(len(stability[setup]))])
                rob_feature.append([np.argmax(np.abs(robustness[setup][i][j]['predict'])) for i in range(len(robustness[setup]))])
            stab_feature = stats.mode(stab_feature, axis=1)
            rob_feature = stats.mode(rob_feature, axis=1)


            performance[stab][setup_names[setup]] = np.mean([np.var([stability[setup][i][j]['predict'][stab_feature.mode[j]] for i in range(len(stability[setup]))]) for j in range(len(stability[setup][0]))])
            performance[rob][setup_names[setup]] = np.mean([np.var([robustness[setup][i][j]['predict'][rob_feature.mode[j]] for i in range(len(robustness[setup]))]) for j in range(len(robustness[setup][0]))])
    except:
        print(setup, robustness[setup])
        
    dataset[key] = performance

dataset
# Out:
# {'abalone': {'Stability': {'LIME Base': 8.239784003441852e-06,
#    'SHAP Base': 9.14816723583937e-36,
#    'LIME': 8.055769344191296e-06,
#    'SHAP': 1.9018558200823955e-35,
#    'CE': 5.585196838722984e-35,
#    'PCE': 0.005027276889609353,
#    'FCE': 8.163265306125811e-08,
#    'PFCE': 0.0034493588016513248},
#   'Robustness': {'LIME Base': 0.0008339648233842419,
#    'SHAP Base': 0.00014012043723724918,
#    'LIME': 0.0009112083137154322,
#    'SHAP': 0.00014012043723724918,
#    'CE': 0.00235845426303855,
#    'PCE': 0.02837007965523196,
#    'FCE': 6.002551020407829e-06,
#    'PFCE': 0.005928745872549799},
#   'Prediction Variance': 7.971418367346933e-05},
#  'anacalt': {'Stability': {'LIME Base': 2.092089925210303e-05,
#    'SHAP Base': 1.4444474582904269e-34,
#    'LIME': 2.0124563608044335e-05,
#    'SHAP': 1.4444474582904269e-34,
#    'CE': 6.162975822039155e-35,
#    'PCE': 0.0023531845624509638,
#    'FCE': 0.0,
#    'PFCE': 0.003205060782543759},
#   'Robustness': {'LIME Base': 0.006777460025138875,
#    'SHAP Base': 0.00018263245648470053,
#    'LIME': 0.006776947542348032,
#    'SHAP': 0.00018263245648470053,
#    'CE': 0.01787200738893939,
#    'PCE': 0.03251055303302753,
#    'FCE': 0.0,
#    'PFCE': 0.004455384588888489},
#   'Prediction Variance': 4.5548920944452465e-05},
#  'bank8fh': {'Stability': {'LIME Base': 1.2818185571629813e-05,
#    'SHAP Base': 3.996304634603514e-35,
#    'LIME': 1.2627834811767948e-05,
#    'SHAP': 1.0676874129196738e-34,
#    'CE': 5.392603844284261e-35,
#    'PCE': 0.0038740628755266336,
#    'FCE': 3.9066072982047314e-05,
#    'PFCE': 0.0014857968799745136},
#   'Robustness': {'LIME Base': 0.000703152091154933,
#    'SHAP Base': 8.647708620676505e-05,
#    'LIME': 0.0006720893926338585,
#    'SHAP': 8.647708620676512e-05,
#    'CE': 0.006506303159535151,
#    'PCE': 0.022808857408884844,
#    'FCE': 0.00013658339246444784,
#    'PFCE': 0.003242403459194469},
#   'Prediction Variance': 8.361217283943359e-05},
#  'bank8fm': {'Stability': {'LIME Base': 1.754210545554126e-05,
#    'SHAP Base': 7.177098308380559e-35,
#    'LIME': 1.6788232909498158e-05,
#    'SHAP': 6.803949381655531e-35,
#    'CE': 8.474091755303838e-35,
#    'PCE': 0.001470038475642309,
#    'FCE': 5.077126924150719e-05,
#    'PFCE': 0.0018089638837052527},
#   'Robustness': {'LIME Base': 0.0012014311227259184,
#    'SHAP Base': 8.417014731951041e-05,
#    'LIME': 0.0011912747376418096,
#    'SHAP': 8.417014731951019e-05,
#    'CE': 0.0028934300180064897,
#    'PCE': 0.01585951903749875,
#    'FCE': 0.00011542956543111051,
#    'PFCE': 0.0019566710299421418},
#   'Prediction Variance': 2.2118192619090885e-05},
#  'bank8nh': {'Stability': {'LIME Base': 6.296037420117538e-06,
#    'SHAP Base': 8.06483164212155e-36,
#    'LIME': 6.425236706542718e-06,
#    'SHAP': 3.863896950926892e-35,
#    'CE': 4.4296388720906427e-35,
#    'PCE': 0.0015075400206760693,
#    'FCE': 9.125621292988548e-06,
#    'PFCE': 0.0006314318077923403},
#   'Robustness': {'LIME Base': 0.00028378470791475,
#    'SHAP Base': 3.805206463214796e-05,
#    'LIME': 0.00028925455471515117,
#    'SHAP': 3.8052064632147955e-05,
#    'CE': 0.0073613456007355395,
#    'PCE': 0.013287709244796499,
#    'FCE': 8.30633073007593e-05,
#    'PFCE': 0.0017899139969197852},
#   'Prediction Variance': 0.00013200570674004011},
#  'bank8nm': {'Stability': {'LIME Base': 8.541806667955852e-06,
#    'SHAP Base': 1.1435209044799212e-35,
#    'LIME': 9.549027905539165e-06,
#    'SHAP': 9.750020343460382e-36,
#    'CE': 7.896312771987667e-35,
#    'PCE': 0.0017293636010172794,
#    'FCE': 6.483362239943586e-06,
#    'PFCE': 0.00046489640339884895},
#   'Robustness': {'LIME Base': 0.0003920429858972702,
#    'SHAP Base': 5.2576965855683e-05,
#    'LIME': 0.0004019395534071842,
#    'SHAP': 5.2576965855682955e-05,
#    'CE': 0.0025362345405710502,
#    'PCE': 0.0030403528630945365,
#    'FCE': 3.150541053768788e-05,
#    'PFCE': 0.0004525352406456269},
#   'Prediction Variance': 2.8160171803507938e-05},
#  'comp': {'Stability': {'LIME Base': 9.34810030004566e-06,
#    'SHAP Base': 2.469302997479818e-07,
#    'LIME': 8.443885236522546e-06,
#    'SHAP': 2.59512500422399e-07,
#    'CE': 6.162975822039155e-35,
#    'PCE': 0.03504930854370949,
#    'FCE': 0.0001430490766248349,
#    'PFCE': 0.000593299148540264},
#   'Robustness': {'LIME Base': 0.004689162220730144,
#    'SHAP Base': 9.433719429055274e-05,
#    'LIME': 0.004686850534394149,
#    'SHAP': 9.437416875119042e-05,
#    'CE': 0.004054683236404448,
#    'PCE': 0.041498968905388456,
#    'FCE': 7.40318334863859e-05,
#    'PFCE': 0.0010395143214973193},
#   'Prediction Variance': 9.603052749719285e-06},
#  'concreate': {'Stability': {'LIME Base': 1.561619534081948e-05,
#    'SHAP Base': 2.407412430484045e-35,
#    'LIME': 1.527885765312306e-05,
#    'SHAP': 5.729641584552026e-35,
#    'CE': 1.0977800683007243e-34,
#    'PCE': 0.004558884461988219,
#    'FCE': 7.15944159372672e-07,
#    'PFCE': 0.00403330725004332},
#   'Robustness': {'LIME Base': 0.00023111149761927114,
#    'SHAP Base': 0.00010994327390742414,
#    'LIME': 0.00023846319957154946,
#    'SHAP': 0.00010994327390742364,
#    'CE': 0.006250857915970402,
#    'PCE': 0.0277812110974374,
#    'FCE': 1.1054868339237297e-05,
#    'PFCE': 0.011776329445099565},
#   'Prediction Variance': 0.00034337164682991757},
#  'deltaA': {'Stability': {'LIME Base': 1.962713969937207e-06,
#    'SHAP Base': 2.2870418089598426e-36,
#    'LIME': 1.531250821815607e-06,
#    'SHAP': 2.407412430484045e-36,
#    'CE': 1.1555579666323415e-35,
#    'PCE': 0.004255560709566269,
#    'FCE': 2.7041644131967834e-06,
#    'PFCE': 0.004412560923982221},
#   'Robustness': {'LIME Base': 5.896380863314571e-05,
#    'SHAP Base': 9.824587429579934e-06,
#    'LIME': 5.9605177632746324e-05,
#    'SHAP': 9.824587429579902e-06,
#    'CE': 0.0001166628111291395,
#    'PCE': 0.01056813308889391,
#    'FCE': 2.6178474851273064e-05,
#    'PFCE': 0.011145437052588143},
#   'Prediction Variance': 2.159381287182265e-05},
#  'deltaE': {'Stability': {'LIME Base': 2.0033384761148257e-06,
#    'SHAP Base': 6.770847460736376e-36,
#    'LIME': 2.018061981261108e-06,
#    'SHAP': 9.62964972193618e-36,
#    'CE': 1.5407439555097887e-35,
#    'PCE': 0.006446414821219509,
#    'FCE': 8.606310013717926e-06,
#    'PFCE': 0.006802191969732129},
#   'Robustness': {'LIME Base': 0.00011389777062738238,
#    'SHAP Base': 2.099557125785737e-05,
#    'LIME': 0.00011373107813921779,
#    'SHAP': 2.0995571257857e-05,
#    'CE': 0.0002537731748209139,
#    'PCE': 0.013312697909653524,
#    'FCE': 1.4581618655692975e-05,
#    'PFCE': 0.01022484789666497},
#   'Prediction Variance': 2.87394238683128e-05},
#  'friedm': {'Stability': {'LIME Base': 1.1043218517499506e-05,
#    'SHAP Base': 1.4444474582904268e-35,
#    'LIME': 1.0410759008850012e-05,
#    'SHAP': 7.222237291452134e-36,
#    'CE': 9.62964972193618e-35,
#    'PCE': 0.0032701283360679367,
#    'FCE': 2.5111967921295715e-06,
#    'PFCE': 0.0061000703839819755},
#   'Robustness': {'LIME Base': 0.0004178642040315168,
#    'SHAP Base': 7.249317811206152e-05,
#    'LIME': 0.0004677948248537129,
#    'SHAP': 7.249317811206135e-05,
#    'CE': 0.002564327628974052,
#    'PCE': 0.029279950966236378,
#    'FCE': 5.873910019094503e-05,
#    'PFCE': 0.008662200300042491},
#   'Prediction Variance': 0.0002220894522892144},
#  'kin8fh': {'Stability': {'LIME Base': 5.798046099621182e-06,
#    'SHAP Base': 7.342607912976337e-36,
#    'LIME': 6.5147655902499744e-06,
#    'SHAP': 5.537048590113303e-36,
#    'CE': 1.925929944387236e-35,
#    'PCE': 0.005969686777307059,
#    'FCE': 1.5488368276713966e-05,
#    'PFCE': 0.0038580499804361994},
#   'Robustness': {'LIME Base': 0.00012629268716106326,
#    'SHAP Base': 2.636475143730426e-05,
#    'LIME': 0.0001211231931375415,
#    'SHAP': 2.636475143730443e-05,
#    'CE': 0.0006283174952321674,
#    'PCE': 0.021989911215883597,
#    'FCE': 1.9307937010306033e-05,
#    'PFCE': 0.007926744214875133},
#   'Prediction Variance': 6.4517494101958e-05},
#  'kin8fm': {'Stability': {'LIME Base': 7.962613251882321e-06,
#    'SHAP Base': 1.829633447167874e-35,
#    'LIME': 8.262928969383758e-06,
#    'SHAP': 8.666684749742561e-36,
#    'CE': 7.703719777548944e-36,
#    'PCE': 0.0027541495955824254,
#    'FCE': 1.943010093327261e-06,
#    'PFCE': 0.00712018685661375},
#   'Robustness': {'LIME Base': 0.0001296585446468679,
#    'SHAP Base': 3.526927033865156e-05,
#    'LIME': 0.0001424255448491775,
#    'SHAP': 3.526927033865165e-05,
#    'CE': 0.00045293677178973165,
#    'PCE': 0.010294138851996593,
#    'FCE': 6.3345139662960974e-06,
#    'PFCE': 0.005840247364558523},
#   'Prediction Variance': 3.179140520495513e-05}}

# %%
stab_data = []
rob_data = []
for key in dataset.keys():
    for setup in dataset[key][stab].keys():
        stab_data.append([key, setup, dataset[key][stab][setup]])
        rob_data.append([key, setup, dataset[key][rob][setup]])
    rob_data.append([key, 'Prediction Variance', dataset[key]['Prediction Variance']])

stab_df = pd.DataFrame(stab_data, columns=['Dataset', 'Setup', 'Value'])
rob_df = pd.DataFrame(rob_data, columns=['Dataset', 'Setup', 'Value'])
display(rob_df)
# Out:
#      Dataset                Setup     Value
# 0    abalone            LIME Base  0.000834
# 1    abalone            SHAP Base  0.000140
# 2    abalone                 LIME  0.000911
# 3    abalone                 SHAP  0.000140
# 4    abalone                   CE  0.002358
# ..       ...                  ...       ...
# 112   kin8fm                   CE  0.000453
# 113   kin8fm                  PCE  0.010294
# 114   kin8fm                  FCE  0.000006
# 115   kin8fm                 PFCE  0.005840
# 116   kin8fm  Prediction Variance  0.000032
#
# [117 rows x 3 columns]

# %%
import pandas as pd
import numpy as np

# Assuming stab_df and rob_df are already defined

# Convert 'Setup' column to categorical with the specified order
stab_df['Setup'] = pd.Categorical(stab_df['Setup'], categories=stab_df['Setup'].dropna().unique(), ordered=True)
rob_df['Setup'] = pd.Categorical(rob_df['Setup'], categories=rob_df['Setup'].dropna().unique(), ordered=True)

stab_pivot = stab_df.pivot(index='Dataset', columns='Setup', values='Value')
rob_pivot = rob_df.pivot(index='Dataset', columns='Setup', values='Value')

display(stab_pivot) 
display(stab_df.pivot_table(columns='Setup', values=['Value'], aggfunc=[np.mean]))
display(rob_pivot)
display(rob_df.pivot_table(columns='Setup', values=['Value'], aggfunc=[np.mean]))
stab_pivot.to_csv('stability.csv')
rob_pivot.to_csv('robustness.csv')
# Out:
# Setup      LIME Base     SHAP Base      LIME          SHAP            CE  \
# Dataset
# abalone     0.000008  9.148167e-36  0.000008  1.901856e-35  5.585197e-35
# anacalt     0.000021  1.444447e-34  0.000020  1.444447e-34  6.162976e-35
# bank8fh     0.000013  3.996305e-35  0.000013  1.067687e-34  5.392604e-35
# bank8fm     0.000018  7.177098e-35  0.000017  6.803949e-35  8.474092e-35
# bank8nh     0.000006  8.064832e-36  0.000006  3.863897e-35  4.429639e-35
# bank8nm     0.000009  1.143521e-35  0.000010  9.750020e-36  7.896313e-35
# comp        0.000009  2.469303e-07  0.000008  2.595125e-07  6.162976e-35
# concreate   0.000016  2.407412e-35  0.000015  5.729642e-35  1.097780e-34
# deltaA      0.000002  2.287042e-36  0.000002  2.407412e-36  1.155558e-35
# deltaE      0.000002  6.770847e-36  0.000002  9.629650e-36  1.540744e-35
# friedm      0.000011  1.444447e-35  0.000010  7.222237e-36  9.629650e-35
# kin8fh      0.000006  7.342608e-36  0.000007  5.537049e-36  1.925930e-35
# kin8fm      0.000008  1.829633e-35  0.000008  8.666685e-36  7.703720e-36
#
# Setup           PCE           FCE      PFCE
# Dataset
# abalone    0.005027  8.163265e-08  0.003449
# anacalt    0.002353  0.000000e+00  0.003205
# bank8fh    0.003874  3.906607e-05  0.001486
# bank8fm    0.001470  5.077127e-05  0.001809
# bank8nh    0.001508  9.125621e-06  0.000631
# bank8nm    0.001729  6.483362e-06  0.000465
# comp       0.035049  1.430491e-04  0.000593
# concreate  0.004559  7.159442e-07  0.004033
# deltaA     0.004256  2.704164e-06  0.004413
# deltaE     0.006446  8.606310e-06  0.006802
# friedm     0.003270  2.511197e-06  0.006100
# kin8fh     0.005970  1.548837e-05  0.003858
# kin8fm     0.002754  1.943010e-06  0.007120
#            mean                                                              \
# Setup LIME Base     SHAP Base     LIME          SHAP            CE      PCE
# Value   0.00001  1.899464e-08  0.00001  1.996250e-08  5.392604e-35  0.00602
#
#
# Setup       FCE      PFCE
# Value  0.000022  0.003382
# Setup      LIME Base  SHAP Base      LIME      SHAP        CE       PCE  \
# Dataset
# abalone     0.000834   0.000140  0.000911  0.000140  0.002358  0.028370
# anacalt     0.006777   0.000183  0.006777  0.000183  0.017872  0.032511
# bank8fh     0.000703   0.000086  0.000672  0.000086  0.006506  0.022809
# bank8fm     0.001201   0.000084  0.001191  0.000084  0.002893  0.015860
# bank8nh     0.000284   0.000038  0.000289  0.000038  0.007361  0.013288
# bank8nm     0.000392   0.000053  0.000402  0.000053  0.002536  0.003040
# comp        0.004689   0.000094  0.004687  0.000094  0.004055  0.041499
# concreate   0.000231   0.000110  0.000238  0.000110  0.006251  0.027781
# deltaA      0.000059   0.000010  0.000060  0.000010  0.000117  0.010568
# deltaE      0.000114   0.000021  0.000114  0.000021  0.000254  0.013313
# friedm      0.000418   0.000072  0.000468  0.000072  0.002564  0.029280
# kin8fh      0.000126   0.000026  0.000121  0.000026  0.000628  0.021990
# kin8fm      0.000130   0.000035  0.000142  0.000035  0.000453  0.010294
#
# Setup           FCE      PFCE  Prediction Variance
# Dataset
# abalone    0.000006  0.005929             0.000080
# anacalt    0.000000  0.004455             0.000046
# bank8fh    0.000137  0.003242             0.000084
# bank8fm    0.000115  0.001957             0.000022
# bank8nh    0.000083  0.001790             0.000132
# bank8nm    0.000032  0.000453             0.000028
# comp       0.000074  0.001040             0.000010
# concreate  0.000011  0.011776             0.000343
# deltaA     0.000026  0.011145             0.000022
# deltaE     0.000015  0.010225             0.000029
# friedm     0.000059  0.008662             0.000222
# kin8fh     0.000019  0.007927             0.000065
# kin8fm     0.000006  0.005840             0.000032
#            mean                                                              \
# Setup LIME Base SHAP Base      LIME      SHAP        CE       PCE       FCE
# Value  0.001228  0.000073  0.001236  0.000073  0.004142  0.020816  0.000045
#
#
# Setup      PFCE Prediction Variance
# Value  0.005726            0.000086
