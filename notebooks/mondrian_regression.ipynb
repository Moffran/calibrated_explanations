# %% [markdown]
# # Mondrian Calibrated Explanations for Regression
# ## Demonstrated on the California Housing data set
#
# Author: Tuwe Löfström (tuwe.lofstrom@ju.se)
# Copyright 2023 Tuwe Löfström
# License: BSD 3 clause
# Sources:
# 1. [California Housing data set [kaggle]](https://www.kaggle.com/datasets/camnugent/california-housing-prices)
# 2. [Löfström, T](https://github.com/tuvelofstrom)., [Löfström, H](https://github.com/Moffran)., Johansson, U., Sönströd, C., and [Matela, R](https://github.com/rudymatela). [Calibrated Explanations for Regression](https://arxiv.org/abs/2308.16245). arXiv preprint arXiv:2308.16245.

# %% [markdown]
# ### 1. Import packages, data and train an underlying model

# %% [markdown]
# #### 1.1 Import packages
#
# In the examples below, we will be using `NumPy`, `pandas`, `sklearn`, and `crepes`. From `crepes`, we import `ConformalPredictiveSystem` and some helper functions from `crepes.extras`. `CalibratedExplainer` is imported from `calibrated_explanations`.

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import pandas as pd

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

from calibrated_explanations import CalibratedExplainer, __version__

from crepes import ConformalPredictiveSystem
from crepes.extras import DifficultyEstimator

print(f"calibrated_explanations {__version__}")
# Out:
# calibrated_explanations v0.3.0

# %% [markdown]
# #### 1.2 Import data and train a model
# Let us import the California Housing data set (see sources at the top).

# %%
dataSet = 'housing.csv'
delimiter = ';'
categorical_labels = {8: {0: 'INLAND', 1: 'NEAR BAY', 2: '<1H OCEAN', 3: 'NEAR OCEAN', 4: 'ISLAND'}}

fileName = '../data/reg/' + dataSet
df = pd.read_csv(fileName, delimiter=delimiter, dtype=np.float64)
target = 'median_house_value'
df.dropna(inplace=True)
X, y = df.drop(target,axis=1), df[target] 
feature_names = df.drop(target,axis=1).columns
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value  ocean_proximity
# 0       322.0       126.0         8.3252            452600.0              1.0
# 1      2401.0      1138.0         8.3014            358500.0              1.0
# 2       496.0       177.0         7.2574            352100.0              1.0
# 3       558.0       219.0         5.6431            341300.0              1.0
# 4       565.0       259.0         3.8462            342200.0              1.0

# %% [markdown]
# Let us split the data set into a training and a test set, and further split the training set into a proper training set and a calibration set. Let us fit a random forest to the proper training set. We also set a random seed to be able to rerun the notebook and get the same results.

# %%
num_to_test = 3

trainCalX, testX, trainCalY, testY = train_test_split(X.values, y.values, test_size=num_to_test, random_state=42)
trainX, calX, trainY, calY = train_test_split(trainCalX, trainCalY, test_size=0.33, random_state=42)

model = RandomForestRegressor(n_estimators=100, oob_score=True)

model.fit(trainX,trainY)  

len(trainX), len(calX), len(testX)
# Out:
# (13688, 6742, 3)

# %% [markdown]
# Before extracting an explanation, lets see what the output from a Conformal Predictive System (cps) is for the test instance(s). Three use cases are explored:
# 1. using percentiles to get the lower and upper bounds of an interval.
# 2. using the 50th percentile(s) to get the median prediction which can be used as a calibrated prediction from the underlying model.
# 3. getting the probability of the prediction being below a certain threshold. 250 000 is used as threshold, as it is close to the midpoint in the possible range of prices.

# %%
from crepes.extras import binning
calY_pred = model.predict(calX)
testY_pred = model.predict(testX)

de_var = DifficultyEstimator()

de_var.fit(X=trainX, learner=model, scaler=True)

sigmas_cal_var = de_var.apply(calX)

bins_cal, bin_thresholds = binning(sigmas_cal_var, bins=20)
bins_cal, bin_thresholds = binning(model.predict(calX), bins=20)
cps = ConformalPredictiveSystem()
cps.fit(residuals=calY-calY_pred, bins=bins_cal)

sigmas_test_var = de_var.apply(testX)
bins_test = binning(sigmas_test_var, bins=bin_thresholds)
bins_test = binning(model.predict(testX), bins=bin_thresholds)
interval = cps.predict(y_hat=testY_pred, lower_percentiles=[5,50], higher_percentiles=[95,50], bins=bins_test)

p_values = cps.predict(y_hat=testY_pred, y=250000, bins=bins_test)

print('5th percentile, prediction, 50th percentile, 95th percentile, true value, p-value (cpsd<250000)')
print(*zip(np.round(interval[:,0], decimals=1), 
           np.round(testY_pred, decimals=1), 
           np.round((interval[:,1] + interval[:,3])/2, decimals=1), 
           np.round(interval[:,2], decimals=1), 
           np.round(testY,decimals=1), 
           np.round(p_values*100, decimals=1)),sep='\n')
# Out:
# 5th percentile, prediction, 50th percentile, 95th percentile, true value, p-value (cpsd<250000)
# (138271.0, 210387.0, 202168.0, 352073.0, 245800.0, 87.7)
# (109712.0, 162740.0, 158335.0, 235686.0, 137900.0, 95.6)
# (133778.0, 186693.0, 180284.0, 279189.0, 218200.0, 93.7)

# %% [markdown]
# Create the `CalibratedExplainer` by feeding the model, the calibration set, and mode='regression' as a minimum.

# %%
ce = CalibratedExplainer(model, 
                        calX, 
                        calY, 
                        feature_names=feature_names, 
                        categorical_labels=categorical_labels,
                        mode='regression')  
ce_bins = CalibratedExplainer(model, 
                        calX, 
                        calY, 
                        feature_names=feature_names, 
                        categorical_labels=categorical_labels,
                        mode='regression',
                        bins=bins_cal)  
ce_var = CalibratedExplainer(model, 
                        calX, 
                        calY, 
                        feature_names=feature_names, 
                        categorical_labels=categorical_labels,
                        mode='regression',
                        difficulty_estimator=de_var)  
ce_all = CalibratedExplainer(model, 
                        calX, 
                        calY, 
                        feature_names=feature_names, 
                        categorical_labels=categorical_labels,
                        mode='regression',
                        difficulty_estimator=de_var,
                        bins=bins_cal) 
display(ce)
display(ce_var)
display(ce_bins)
display(ce_all)
# Out:
# CalibratedExplainer:
# 	                mode=regression
# 	                mondrian=False
# 	                discretizer=<class 'NoneType'>
# 	                model=RandomForestRegressor(oob_score=True)
# 	                difficulty_estimator=None
# CalibratedExplainer:
# 	                mode=regression
# 	                mondrian=False
# 	                discretizer=<class 'NoneType'>
# 	                model=RandomForestRegressor(oob_score=True)
# 	                difficulty_estimator=DifficultyEstimator(fitted=True, type=variance, scaler=True, beta=0.01, oob=False)
# CalibratedExplainer:
# 	                mode=regression
# 	                mondrian=True
# 	                discretizer=<class 'NoneType'>
# 	                model=RandomForestRegressor(oob_score=True)
# 	                difficulty_estimator=None
# CalibratedExplainer:
# 	                mode=regression
# 	                mondrian=True
# 	                discretizer=<class 'NoneType'>
# ...

# %% [markdown]
# In the examples below, all intervals will be with 90% certainty and can be either two-sided or one-sided. The intervals are defined by assigning a pair of values to the `low_high_percentiles` attribute (see below).

# %%
tsi = (5,95) # two-sided interval with 90% confidence
osli = (10,np.inf) # one-sided lower-bounded interval with 90% confidence
osui = (-np.inf,90) # one-sided upper-bounded interval with 90% confidence

# %% [markdown]
# #### Two-sided interval with 95% confidence
# Since we are defining two-sided intervals, `low_high_percentiles=tsi`.
#
# Once the explanations are extracted, we can visualize them using various plots. The regular plot include an uncertainty estimate for the prediction and the weights of the most influential features. The shaded area is the the prediction interval with 95% confidence. The solid line in the middle of the shaded interval is the median in the conformal predictive distribution.
#
# Regular plots are shown by calling the function `plot_all` or `plot_explanation`, with `n_features_to_show` indicating the number of features to include (default 10), in order of importance.

# %%
factual_explanation = ce.explain_factual(testX, low_high_percentiles=tsi)
display(ce)
factual_explanation_var = ce_var.explain_factual(testX, low_high_percentiles=tsi)
display(ce_var)
factual_explanation_bins = ce_bins.explain_factual(testX, low_high_percentiles=tsi, bins=bins_test)
display(ce_bins)
factual_explanation_all = ce_all.explain_factual(testX, low_high_percentiles=tsi, bins=bins_test)
display(ce_all)
# Out:
# CalibratedExplainer:
# 	                mode=regression
# 	                mondrian=False
# 	                discretizer=<class 'calibrated_explanations._discretizers.BinaryRegressorDiscretizer'>
# 	                model=RandomForestRegressor(oob_score=True)
# 	                difficulty_estimator=None
# CalibratedExplainer:
# 	                mode=regression
# 	                mondrian=False
# 	                discretizer=<class 'calibrated_explanations._discretizers.BinaryRegressorDiscretizer'>
# 	                model=RandomForestRegressor(oob_score=True)
# 	                difficulty_estimator=DifficultyEstimator(fitted=True, type=variance, scaler=True, beta=0.01, oob=False)
# CalibratedExplainer:
# 	                mode=regression
# 	                mondrian=True
# 	                discretizer=<class 'calibrated_explanations._discretizers.BinaryRegressorDiscretizer'>
# 	                model=RandomForestRegressor(oob_score=True)
# 	                difficulty_estimator=None
# ...

# %%
for i in range(len(testY)):     
    factual_explanation.plot_explanation(i, n_features_to_show=4)
    factual_explanation_var.plot_explanation(i, n_features_to_show=4)
    factual_explanation_bins.plot_explanation(i, n_features_to_show=4)
    factual_explanation_all.plot_explanation(i, n_features_to_show=4)

# %% [markdown]
# Uncertainty plots are similar to regular plots but also provide an uncertainty estimate for the impact of each feature. Here, the shaded area is the range of possible changes with the assigned confidence interval (here a two-sided interval with 95% confidence, as defined above). The solid line in the middle of the shaded interval is the median in the conformal predictive distribution.
#
# To get uncertainty plots, simply call `plot_all` or `plot_explanation` with the parameter `uncertainty=True`.

# %%
for i in range(len(testY)):     
    factual_explanation.plot_explanation(i, n_features_to_show=4, uncertainty=True)
    factual_explanation_var.plot_explanation(i, n_features_to_show=4, uncertainty=True)
    factual_explanation_bins.plot_explanation(i, n_features_to_show=4, uncertainty=True)
    factual_explanation_all.plot_explanation(i, n_features_to_show=4, uncertainty=True)

# %% [markdown]
# It is also possible to add conjunctive rules through the `add_conjunctions` method. Two rules are combined by default when called without parameters but up to three rules can be combined if the parameter `num_rule_size=3`. By default, only the 5 most important rules are combined with other rules but this number can also be adjusted through the parameter `num_to_include`.

# %%
factual_explanation.add_conjunctions(max_rule_size=3)
factual_explanation_var.add_conjunctions(max_rule_size=3)
factual_explanation_bins.add_conjunctions(max_rule_size=3)
factual_explanation_all.add_conjunctions(max_rule_size=3)
for i in range(len(testY)):     
    factual_explanation.plot_explanation(i, n_features_to_show=4, uncertainty=True)
    factual_explanation_var.plot_explanation(i, n_features_to_show=4, uncertainty=True)
    factual_explanation_bins.plot_explanation(i, n_features_to_show=4, uncertainty=True)
    factual_explanation_all.plot_explanation(i, n_features_to_show=4, uncertainty=True)

# %% [markdown]
# If the conjunctions are no longer wanted, they can be removed with `remove_conjunctions`.

# %%
factual_explanation.remove_conjunctions()
factual_explanation_var.remove_conjunctions()
factual_explanation_bins.remove_conjunctions()
factual_explanation_all.remove_conjunctions()
for i in range(len(testY)):     
    factual_explanation.plot_explanation(i, n_features_to_show=4, uncertainty=True)
    factual_explanation_var.plot_explanation(i, n_features_to_show=4, uncertainty=True)
    factual_explanation_bins.plot_explanation(i, n_features_to_show=4, uncertainty=True)
    factual_explanation_all.plot_explanation(i, n_features_to_show=4, uncertainty=True)

# %% [markdown]
# #### One-sided lower-bounded interval with 95% confidence
# To change confidence or interval type, new explanations must be extracted. Here `low_high_percentiles=osli` to get a one-sided lower-bounded interval.

# %%
factual_explanation = ce.explain_factual(testX, low_high_percentiles=osli)
factual_explanation_var = ce_var.explain_factual(testX, low_high_percentiles=osli)
factual_explanation_bins = ce_bins.explain_factual(testX, low_high_percentiles=osli, bins=bins_test)
factual_explanation_all = ce_all.explain_factual(testX, low_high_percentiles=osli, bins=bins_test)

for i in range(len(testY)):     
    factual_explanation.plot_explanation(i, n_features_to_show=4)
    factual_explanation_var.plot_explanation(i, n_features_to_show=4)
    factual_explanation_bins.plot_explanation(i, n_features_to_show=4)
    factual_explanation_all.plot_explanation(i, n_features_to_show=4)

# %%
factual_explanation.add_conjunctions(max_rule_size=3)
factual_explanation_var.add_conjunctions(max_rule_size=3)
factual_explanation_bins.add_conjunctions(max_rule_size=3)
factual_explanation_all.add_conjunctions(max_rule_size=3)
for i in range(len(testY)):     
    factual_explanation.plot_explanation(i, n_features_to_show=4)
    factual_explanation_var.plot_explanation(i, n_features_to_show=4)
    factual_explanation_bins.plot_explanation(i, n_features_to_show=4)
    factual_explanation_all.plot_explanation(i, n_features_to_show=4)

# %% [markdown]
# #### One-sided upper-bounded interval with 95% confidence
# Assign `low_high_percentiles=osui` to get a one-sided upper-bounded interval.

# %% [markdown]
# #### Two-sided counterfactual rules

# %%
counterfactual_explanation = ce.explain_counterfactual(testX, low_high_percentiles=tsi)
display(ce)
counterfactual_explanation_var = ce_var.explain_counterfactual(testX, low_high_percentiles=tsi)
display(ce_var)
counterfactual_explanation_bins = ce_bins.explain_counterfactual(testX, low_high_percentiles=tsi, bins=bins_test)
display(ce_bins)
counterfactual_explanation_all = ce_all.explain_counterfactual(testX, low_high_percentiles=tsi, bins=bins_test)
display(ce_all)
# Out:
# CalibratedExplainer:
# 	                mode=regression
# 	                mondrian=False
# 	                discretizer=<class 'calibrated_explanations._discretizers.RegressorDiscretizer'>
# 	                model=RandomForestRegressor(oob_score=True)
# 	                difficulty_estimator=None
# CalibratedExplainer:
# 	                mode=regression
# 	                mondrian=False
# 	                discretizer=<class 'calibrated_explanations._discretizers.RegressorDiscretizer'>
# 	                model=RandomForestRegressor(oob_score=True)
# 	                difficulty_estimator=DifficultyEstimator(fitted=True, type=variance, scaler=True, beta=0.01, oob=False)
# CalibratedExplainer:
# 	                mode=regression
# 	                mondrian=True
# 	                discretizer=<class 'calibrated_explanations._discretizers.RegressorDiscretizer'>
# 	                model=RandomForestRegressor(oob_score=True)
# 	                difficulty_estimator=None
# CalibratedExplainer:
# ...

# %%
for i in range(len(testY)):     
    counterfactual_explanation.plot_explanation(i, n_features_to_show=4)
    counterfactual_explanation_var.plot_explanation(i, n_features_to_show=4)
    counterfactual_explanation_bins.plot_explanation(i, n_features_to_show=4)
    counterfactual_explanation_all.plot_explanation(i, n_features_to_show=4)

# %% [markdown]
# #### One-sided counterfactual rules

# %%
counterfactual_explanation = ce.explain_counterfactual(testX, low_high_percentiles=osli)
counterfactual_explanation_var = ce_var.explain_counterfactual(testX, low_high_percentiles=osli)
counterfactual_explanation_bins = ce_bins.explain_counterfactual(testX, low_high_percentiles=osli, bins=bins_test)
counterfactual_explanation_all = ce_all.explain_counterfactual(testX, low_high_percentiles=osli, bins=bins_test)
for i in range(len(testY)):     
    counterfactual_explanation.plot_explanation(i, n_features_to_show=4)
    counterfactual_explanation_var.plot_explanation(i, n_features_to_show=4)
    counterfactual_explanation_bins.plot_explanation(i, n_features_to_show=4)
    counterfactual_explanation_all.plot_explanation(i, n_features_to_show=4)

# %% [markdown]
# ### Normalized explanations
# Normalized explanations can be achieved through the use k-nearest neighbor or by using the variance (if using an ensemble model like a RandomForestRegressor).
#
# #### Normalized explanations using knn

# %% [markdown]
# There are three ways to set the difficulty estimator (sigma) for the CalibratedExplainer when using k-nearest neighbor.
# * alternative 1: by the (Euclidean) distances to the nearest neighbors
# * alternative 2: by the standard deviation of the targets of the nearest neighbors
# * alternative 3: by the absolute errors of the k nearest neighbors
#
# See the documentation of crepes for further details on how the `DifficultyEstimator` works, see [here](https://crepes.readthedocs.io/en/latest/).

# %% [markdown]
# ### Probabilistic Calibrated Explanations
# The explanations below are using the possibility to assign a threshold to provide a probabilistic prediction for the probability of being below the threshold, instead of using an interval. The types of explanations are the same as for explanations for regression.

# %%
factual_explanation = ce.explain_factual(testX, threshold=180000)
display(ce)
factual_explanation_var = ce_var.explain_factual(testX, threshold=180000)
display(ce_var)
factual_explanation_bins = ce_bins.explain_factual(testX, threshold=180000, bins=bins_test)
display(ce_bins)
factual_explanation_all = ce_all.explain_factual(testX, threshold=180000, bins=bins_test)
display(ce_all)
# Out:
# CalibratedExplainer:
# 	                mode=regression
# 	                mondrian=False
# 	                discretizer=<class 'calibrated_explanations._discretizers.BinaryRegressorDiscretizer'>
# 	                model=RandomForestRegressor(oob_score=True)
# 	                difficulty_estimator=None
# CalibratedExplainer:
# 	                mode=regression
# 	                mondrian=False
# 	                discretizer=<class 'calibrated_explanations._discretizers.BinaryRegressorDiscretizer'>
# 	                model=RandomForestRegressor(oob_score=True)
# 	                difficulty_estimator=DifficultyEstimator(fitted=True, type=variance, scaler=True, beta=0.01, oob=False)
# c:\Users\loftuw\AppData\Local\anaconda3\envs\ce\lib\site-packages\venn_abers\venn_abers.py:102: RuntimeWarning: All-NaN slice encountered
#   if np.sum(np.isnan(np.nanmin(grads))) == 0:
# ...

# %%
for i in range(len(testY)):     
    factual_explanation.plot_explanation(i, n_features_to_show=4)
    factual_explanation_var.plot_explanation(i, n_features_to_show=4)
    factual_explanation_bins.plot_explanation(i, n_features_to_show=4)
    factual_explanation_all.plot_explanation(i, n_features_to_show=4)
